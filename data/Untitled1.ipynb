# %%
import pandas as pd 
import numpy as np

# %%
a=["Casablanca", "Rabat","Fès","Marrakech","Tanger","Salé","Meknès","Oujda"
,"Al-Hoceima","Agadir","Kenitra","Nador","Safi","El-Jadida","Tétouan","Khouribga","Beni-Mellal","Essaouira","Mohammedia","Taza",]

# %%
b=["Laâyoune",
"Dakhla",
"Zagora",
"Settat",
"Ouarzazate",
"Guelmim",
"Khemisset",
"Boujdour",
"Sidi-ifni",
"Berkane",
"Taounate",
"Sefrou",
"Berrchid"]

# %%
l=[]
for i in a:
    l+=[f'https://www.google.com/maps/search/banks+in+{i}']

# %%
l
# Out:
# ['https://www.google.com/maps/search/banks+in+Casablanca',
#  'https://www.google.com/maps/search/banks+in+Rabat',
#  'https://www.google.com/maps/search/banks+in+Fès',
#  'https://www.google.com/maps/search/banks+in+Marrakech',
#  'https://www.google.com/maps/search/banks+in+Tanger',
#  'https://www.google.com/maps/search/banks+in+Salé',
#  'https://www.google.com/maps/search/banks+in+Meknès',
#  'https://www.google.com/maps/search/banks+in+Oujda',
#  'https://www.google.com/maps/search/banks+in+Al-Hoceima',
#  'https://www.google.com/maps/search/banks+in+Agadir',
#  'https://www.google.com/maps/search/banks+in+Kenitra',
#  'https://www.google.com/maps/search/banks+in+Nador',
#  'https://www.google.com/maps/search/banks+in+Safi',
#  'https://www.google.com/maps/search/banks+in+El-Jadida',
#  'https://www.google.com/maps/search/banks+in+Tétouan',
#  'https://www.google.com/maps/search/banks+in+Khouribga',
#  'https://www.google.com/maps/search/banks+in+Beni-Mellal',
# ...

# %%
https://www.google.com/maps/search/banks+in+Casablanca
https://www.google.com/maps/search/banks+in+Rabat
https://www.google.com/maps/search/banks+in+Fès
https://www.google.com/maps/search/banks+in+Marrakech
https://www.google.com/maps/search/banks+in+Tanger
https://www.google.com/maps/search/banks+in+Salé
https://www.google.com/maps/search/banks+in+Meknès
https://www.google.com/maps/search/banks+in+Oujda
https://www.google.com/maps/search/banks+in+Al-Hoceima
https://www.google.com/maps/search/banks+in+Agadir
https://www.google.com/maps/search/banks+in+Kenitra
https://www.google.com/maps/search/banks+in+Nador
https://www.google.com/maps/search/banks+in+Safi
https://www.google.com/maps/search/banks+in+El-Jadida
https://www.google.com/maps/search/banks+in+Tétouan
https://www.google.com/maps/search/banks+in+Khouribga
https://www.google.com/maps/search/banks+in+Beni-Mellal
https://www.google.com/maps/search/banks+in+Essaouira
https://www.google.com/maps/search/banks+in+Mohammedia
https://www.google.com/maps/search/banks+in+Taza

# %%
l=[]
for i in b:
    l+=[f'https://www.google.com/maps/search/banks+in+{i}']

# %%
https://www.google.com/maps/search/banks+in+Laâyoune
https://www.google.com/maps/search/banks+in+Dakhla
https://www.google.com/maps/search/banks+in+Zagora
https://www.google.com/maps/search/banks+in+Settat
https://www.google.com/maps/search/banks+in+Ouarzazate
https://www.google.com/maps/search/banks+in+Guelmim
https://www.google.com/maps/search/banks+in+Khemisset
https://www.google.com/maps/search/banks+in+Boujdour
https://www.google.com/maps/search/banks+in+Sidi-ifni
https://www.google.com/maps/search/banks+in+Berkane
https://www.google.com/maps/search/banks+in+Taounate
https://www.google.com/maps/search/banks+in+Sefrou
https://www.google.com/maps/search/banks+in+Berrchid
# Out:
# ['https://www.google.com/maps/search/banks+in+Laâyoune',
#  'https://www.google.com/maps/search/banks+in+Dakhla',
#  'https://www.google.com/maps/search/banks+in+Zagora',
#  'https://www.google.com/maps/search/banks+in+Settat',
#  'https://www.google.com/maps/search/banks+in+Ouarzazate',
#  'https://www.google.com/maps/search/banks+in+Guelmim',
#  'https://www.google.com/maps/search/banks+in+Khemisset',
#  'https://www.google.com/maps/search/banks+in+Boujdour',
#  'https://www.google.com/maps/search/banks+in+Sidi-ifni',
#  'https://www.google.com/maps/search/banks+in+Berkane',
#  'https://www.google.com/maps/search/banks+in+Taounate',
#  'https://www.google.com/maps/search/banks+in+Sefrou',
#  'https://www.google.com/maps/search/banks+in+Berrchid']

# %%
d1=pd.read_excel("1.xlsx")
d2=pd.read_excel("2.xlsx")

# %%
d1
# Out:
#                                                 address  \
# 0     Boîte postale 133 Hay Amezrou route principal ...
# 1             15 Ave Atlas-Zaouite, Zagora 45900, Maroc
# 2        Numéro 28 Bis, Avenue Mohamed V, Zagora, Maroc
# 3     Bd Mohamed 5, Zagora, Marocشارع محمد الخامس، ز...
# 4               85J6+6W6, Zagora, Maroc85J6+6W6، زاڭورة
# ...                                                 ...
# 1165  M3R3+387, Boulevard Mohamed Bahnini, Dakhla 73000
# 1166  M3R3+387, Boulevard Mohamed Bahnini, Dakhla 73000
# 1167  M3R3+387, Boulevard Mohamed Bahnini, Dakhla 73000
# 1168  Avenue Mohammed VI, Place Bir Anzarane, Guelmi...
# 1169  XWVW+35V, Guelmim 81000, MarocXWVW+35V، ڭلميم ...
#
#                        categoryName                   cid     city  \
# 0     Service de transfert d'argent  13422431996109754356   Zagora
# 1                             Poste   1706403930956525421   Zagora
# 2     Service de transfert d'argent   1611100325498863237   Zagora
# ...

# %%
b=pd.concat((d2,d1),axis=0)

# %%
b
# Out:
#                                                 address categoryName  \
# 0      Rue Abou Abdellah Nafii, Casablanca 20250, Maroc       Banque
# 1      Rue Abou Abdellah Nafii, Casablanca 20250, Maroc       Banque
# 2      Rue Abou Abdellah Nafii, Casablanca 20250, Maroc       Banque
# 3      Rue Abou Abdellah Nafii, Casablanca 20250, Maroc       Banque
# 4      Rue Abou Abdellah Nafii, Casablanca 20250, Maroc       Banque
# ...                                                 ...          ...
# 1165  M3R3+387, Boulevard Mohamed Bahnini, Dakhla 73000       Banque
# 1166  M3R3+387, Boulevard Mohamed Bahnini, Dakhla 73000       Banque
# 1167  M3R3+387, Boulevard Mohamed Bahnini, Dakhla 73000       Banque
# 1168  Avenue Mohammed VI, Place Bir Anzarane, Guelmi...       Banque
# 1169  XWVW+35V, Guelmim 81000, MarocXWVW+35V، ڭلميم ...       Banque
#
#                        cid        city  location/lat  location/lng  \
# 0       608978182545380059  Casablanca     33.585603     -7.633682
# ...

# %%
c=b.to_excel('banks.xlsx', index=False)

# %%
b=b[["title"]]

# %%
b=b.query
